# %%
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from CakeAnalyzer import load_transactions, rewards_report, plot_report

# %%
# download transactions from your CakeDefi profile, and place the path here
PATH = './cake151121.csv'

# %%
data = load_transactions(PATH)

# %%
report = rewards_report(data=data,asset='DFI')

# %%
fig, ax = plot_report(report, second_axis='USD', second_axis_converter=3.33)

# %%
report = rewards_report(data=data,asset='BTC')

# %%
fig, ax = plot_report(report, second_axis='USD', second_axis_converter=3.33)
